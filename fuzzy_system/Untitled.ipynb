# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import anfis as an
# seed for reproducing same results
#seed = 9
#np.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %%
filename1 = pd.read_csv("heart-statlog.csv")
filename1
# Out:
#      63  1  1.1  145  233  1.2  2  150  0  3  0.1  6  1.3
# 0    67  1    4  160  286    0  2  108  1  2    3  3    0
# 1    67  1    4  120  229    0  2  129  1  2    2  7    0
# 2    37  1    3  130  250    0  0  187  0  3    0  3    1
# 3    41  0    2  130  204    0  2  172  0  1    0  3    1
# 4    56  1    2  120  236    0  0  178  0  1    0  3    1
# 5    62  0    4  140  268    0  2  160  0  3    2  3    0
# 6    57  0    4  120  354    0  0  163  1  1    0  3    1
# 7    63  1    4  130  254    0  2  147  0  2    1  7    0
# 8    53  1    4  140  203    1  2  155  1  3    0  7    0
# 9    57  1    4  140  192    0  0  148  0  2    0  6    1
# 10   56  0    2  140  294    0  2  153  0  2    0  3    1
# 11   56  1    3  130  256    1  2  142  1  2    1  6    0
# 12   44  1    2  120  263    0  0  173  0  1    0  7    1
# 13   52  1    3  172  199    1  0  162  0  1    0  7    1
# 14   57  1    3  150  168    0  0  174  0  1    0  3    1
# ...

# %%
X_train=filename1.iloc[0:650,0:12]
Y_train=filename1.iloc[0:650:,13:]

# %%
X_test=filename1.iloc[651:871,0:12]
Y_test=filename1.iloc[651:871,12:13]
Y_test
# Out:
#      1.3
# 651    1
# 652    0
# 653    0
# 654    0
# 655    0
# 656    0
# 657    0
# 658    0
# 659    1
# 660    0
# 661    0
# 662    0
# 663    1
# 664    1
# 665    1
# 666    0
# 667    0
# 668    0
# 669    0
# 670    0
# 671    0
# 672    1
# 673    0
# 674    1
# 675    1
# 676    1
# 677    1
# 678    1
# 679    1
# 680    0
# ..   ...
# 841    1
# 842    0
# 843    0
# 844    0
# 845    1
# 846    0
# 847    1
# 848    0
# 849    1
# 850    0
# 851    1
# 852    1
# 853    1
# 854    0
# 855    0
# 856    0
# 857    1
# 858    0
# 859    1
# 860    1
# 861    1
# 862    0
# 863    1
# 864    1
# 865    1
# 866    1
# 867    1
# 868    1
# 869    0
# 870    0
#
# [220 rows x 1 columns]

# %%
model = Sequential()
model.add(Dense(10, input_dim=12, init='uniform', activation='tanh'))
model.add(Dense(11, init='uniform', activation='tanh'))
model.add(Dense(1, init='uniform', activation='sigmoid'))
# Out:
# c:\users\jd\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, kernel_initializer="uniform", input_dim=12, activation="tanh")`
#
# c:\users\jd\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(11, kernel_initializer="uniform", activation="tanh")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\jd\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform", activation="sigmoid")`
#   after removing the cwd from sys.path.
